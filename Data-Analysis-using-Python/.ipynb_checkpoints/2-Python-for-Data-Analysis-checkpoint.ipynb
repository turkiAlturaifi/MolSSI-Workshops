# %% [markdown]
# # MolISS Workeshop 2
# # Python for Data Analysis
# you can find more info here https://education.molssi.org/python-data-analysis/01-numpy-arrays/index.html

# %% [markdown]
# ## Section 2: Using pandas for data analysis
# __Questions__
#
# What is pandas?
#
# How do I access data in a pandas dataframe?
#
# __Objectives__
#
# Use pandas to examine and analyze data
#
# Pandas is another Python package which is very popular for data analysis. The key feature of pandas is the dataframe. In this lesson, we will cover pandas dataframes and some basic analysis.

# %% [markdown]
# ### What is pandas?
# You are already familiar with the data analyis library numpy and the numpy array. NumPy is useful when you are working with data that is all numeric. Pandas, however, is capable of handling data of lots of different types. It is designed to make working with “relational” or “labeled” data easy and intuitive. Central to the pandas package are the special data structures called pandas Series and DataFrames. Pandas dataframes are 2 dimensional and tabular, and is particularly suited to data which is heterogenous and in columns, like an SQL table or Excel spreadsheet. In fact, there are even functions which allow you to read data directly from excel spreadsheets or SQL databases (more on this later).
#
# Pandas is built to closely work with NumPy. Many functions which work on NumPy arrays will also work on Pandas DataFrames.

# %%
import pandas as pd

# %% [markdown]
# ### Reading data
#
# Today, we will be working with a data set that contains information about the elements in the periodic table (2019 is the International Year of the Periodic Table!).The data is a csv (comma separated value) file from PubChem. You can download the file here.
#
# Once you have the file downloaded and saved in your directory, we will load it into pandas. This file is a csv (comma separated value) file, so we will load it using the pd.read_csv command.

# %%
periodic_tabel = pd.read_csv('PubChemElements_all.csv')

# %% [markdown]
# ### Examining the data
# The variable periodic_data is now a pandas DataFrame with the information contained in the csv file. You can examine the DataFrame using the .head() method. This shows the first 5 rows stored in the DataFrame.

# %%
periodic_tabel.head() # first 5 rows
# Out:
#    AtomicNumber Symbol       Name  AtomicMass CPKHexColor  \
# 0             1      H   Hydrogen    1.008000      FFFFFF
# 1             2     He     Helium    4.002600      D9FFFF
# 2             3     Li    Lithium    7.000000      CC80FF
# 3             4     Be  Beryllium    9.012183      C2FF00
# 4             5      B      Boron   10.810000      FFB5B5
#
#   ElectronConfiguration  Electronegativity  AtomicRadius  IonizationEnergy  \
# 0                   1s1               2.20         120.0            13.598
# 1                   1s2                NaN         140.0            24.587
# 2               [He]2s1               0.98         182.0             5.392
# 3               [He]2s2               1.57         153.0             9.323
# 4           [He]2s2 2p1               2.04         192.0             8.298
#
#    ElectronAffinity OxidationStates StandardState  MeltingPoint  BoilingPoint  \
# 0             0.754          +1, -1           Gas         13.81         20.28
# 1               NaN               0           Gas          0.95          4.22
# 2             0.618              +1         Solid        453.65       1615.00
# 3               NaN              +2         Solid       1560.00       2744.00
# 4             0.277              +3         Solid       2348.00       4273.00
#
#     Density            GroupBlock YearDiscovered
# 0  0.000090              Nonmetal           1766
# 1  0.000179             Noble gas           1868
# 2  0.534000          Alkali metal           1817
# 3  1.850000  Alkaline earth metal           1798
# 4  2.370000             Metalloid           1808

# %%
periodic_tabel.tail() # last 5 rows
# Out:
#      AtomicNumber Symbol         Name  AtomicMass CPKHexColor  \
# 113           114     Fl    Flerovium     289.191         NaN
# 114           115     Mc    Moscovium     290.196         NaN
# 115           116     Lv  Livermorium     293.205         NaN
# 116           117     Ts   Tennessine     294.211         NaN
# 117           118     Og    Oganesson     294.214         NaN
#
#                  ElectronConfiguration  Electronegativity  AtomicRadius  \
# 113  [Rn]7s2 7p2 5f14 6d10 (predicted)                NaN         180.0
# 114  [Rn]7s2 7p3 5f14 6d10 (predicted)                NaN         187.0
# 115  [Rn]7s2 7p4 5f14 6d10 (predicted)                NaN         183.0
# 116  [Rn]7s2 7p5 5f14 6d10 (predicted)                NaN         138.0
# 117  [Rn]7s2 7p6 5f14 6d10 (predicted)                NaN           NaN
#
#      IonizationEnergy  ElectronAffinity OxidationStates  \
# 113               NaN               NaN             NaN
# 114               NaN               NaN             NaN
# 115               NaN               NaN             NaN
# 116               NaN               NaN             NaN
# 117               NaN               NaN             NaN
#
#               StandardState  MeltingPoint  BoilingPoint  Density  \
# 113  Expected to be a Solid           NaN           NaN      NaN
# 114  Expected to be a Solid           NaN           NaN      NaN
# 115  Expected to be a Solid           NaN           NaN      NaN
# 116  Expected to be a Solid           NaN           NaN      NaN
# 117    Expected to be a Gas           NaN           NaN      NaN
#
#                 GroupBlock YearDiscovered
# 113  Post-transition metal           1998
# 114  Post-transition metal           2003
# 115  Post-transition metal           2000
# 116                Halogen           2010
# 117              Noble gas           2006

# %%
periodic_tabel.info() # info about the csv file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AtomicNumber           118 non-null    int64
#  1   Symbol                 118 non-null    object
#  2   Name                   118 non-null    object
#  3   AtomicMass             118 non-null    float64
#  4   CPKHexColor            108 non-null    object
#  5   ElectronConfiguration  118 non-null    object
#  6   Electronegativity      95 non-null     float64
#  7   AtomicRadius           113 non-null    float64
#  8   IonizationEnergy       102 non-null    float64
#  9   ElectronAffinity       57 non-null     float64
#  10  OxidationStates        103 non-null    object
#  11  StandardState          118 non-null    object
#  12  MeltingPoint           103 non-null    float64
#  13  BoilingPoint           93 non-null     float64
#  14  Density                96 non-null     float64
#  15  GroupBlock             118 non-null    object
#  16  YearDiscovered         118 non-null    object
# dtypes: float64(8), int64(1), object(8)
# memory usage: 15.8+ KB

# %%
periodic_tabel.describe() #descriptive statistics
# Out:
#        AtomicNumber  AtomicMass  Electronegativity  AtomicRadius  \
# count    118.000000  118.000000          95.000000    113.000000
# mean      59.500000  146.607635           1.732316    201.902655
# std       34.207699   89.845304           0.635187     42.025707
# min        1.000000    1.008000           0.700000    120.000000
# 25%       30.250000   66.480000           1.290000    180.000000
# 50%       59.500000  142.573850           1.620000    202.000000
# 75%       88.750000  226.777165           2.170000    229.000000
# max      118.000000  294.214000           3.980000    348.000000
#
#        IonizationEnergy  ElectronAffinity  MeltingPoint  BoilingPoint  \
# count        102.000000         57.000000    103.000000     93.000000
# mean           7.997255          1.072140   1273.740553   2536.212473
# std            3.339066          0.879163    888.853859   1588.410919
# min            3.894000          0.079000      0.950000      4.220000
# 25%            6.020500          0.470000    516.040000   1180.000000
# 50%            6.960000          0.754000   1191.000000   2792.000000
# 75%            8.998500          1.350000   1806.500000   3618.000000
# max           24.587000          3.617000   3823.000000   5869.000000
#
#          Density
# count  96.000000
# mean    7.608001
# std     5.878692
# min     0.000090
# 25%     2.572500
# 50%     7.072000
# 75%    10.275250
# max    22.570000

# %% [markdown]
# ### Accessing Data
# Data in pandas DataFrames are stored in rows and columns.
# #### Accessing data using row and column numbers
# Pandas DataFrames are organized using columns, which we have already discussed and index for the rows.
#
# To access data using the row number and column number, use the .iloc method.
#
# Data in pandas DataFrames can be accessed using slices in the same way as NumPy arrays using the iloc method.

# %%
# access row # 35, starting from 0

periodic_tabel.iloc[35]
# Out:
# AtomicNumber                           36
# Symbol                                 Kr
# Name                              Krypton
# AtomicMass                           83.8
# CPKHexColor                        5CB8D1
# ElectronConfiguration    [Ar]4s2 3d10 4p6
# Electronegativity                     3.0
# AtomicRadius                        202.0
# IonizationEnergy                     14.0
# ElectronAffinity                      NaN
# OxidationStates                         0
# StandardState                         Gas
# MeltingPoint                       115.79
# BoilingPoint                       119.93
# Density                          0.003733
# GroupBlock                      Noble gas
# YearDiscovered                       1898
# Name: 35, dtype: object

# %%
periodic_tabel.iloc[35:45,2] #symbols
# Out:
# 35       Krypton
# 36      Rubidium
# 37     Strontium
# 38       Yttrium
# 39     Zirconium
# 40       Niobium
# 41    Molybdenum
# 42    Technetium
# 43     Ruthenium
# 44       Rhodium
# Name: Name, dtype: object

# %%
# row 5
print(periodic_tabel.iloc[5])
# rows 30 to the end
print(periodic_tabel.iloc[30:])
# column 2 to 4, and row 50 to the end, every other row
print(periodic_tabel.iloc[50::2,2::5])
# Out:
# AtomicNumber                       6
# Symbol                             C
# Name                          Carbon
# AtomicMass                    12.011
# CPKHexColor                   909090
# ElectronConfiguration    [He]2s2 2p2
# Electronegativity               2.55
# AtomicRadius                   170.0
# IonizationEnergy               11.26
# ElectronAffinity               1.263
# OxidationStates           +4, +2, -4
# StandardState                  Solid
# MeltingPoint                  3823.0
# BoilingPoint                  4098.0
# Density                        2.267
# GroupBlock                  Nonmetal
# YearDiscovered               Ancient
# Name: 5, dtype: object
#      AtomicNumber Symbol         Name  AtomicMass CPKHexColor  \
# 30             31     Ga      Gallium    69.72000      C28F8F
# 31             32     Ge    Germanium    72.63000      668F8F
# 32             33     As      Arsenic    74.92159      BD80E3
# 33             34     Se     Selenium    78.97000      FFA100
# 34             35     Br      Bromine    79.90000      A62929
# ..            ...    ...          ...         ...         ...
# 113           114     Fl    Flerovium   289.19100         NaN
# 114           115     Mc    Moscovium   290.19600         NaN
# 115           116     Lv  Livermorium   293.20500         NaN
# 116           117     Ts   Tennessine   294.21100         NaN
# 117           118     Og    Oganesson   294.21400         NaN
#
#                  ElectronConfiguration  Electronegativity  AtomicRadius  \
# 30                    [Ar]4s2 3d10 4p1               1.81         187.0
# 31                    [Ar]4s2 3d10 4p2               2.01         211.0
# 32                    [Ar]4s2 3d10 4p3               2.18         185.0
# 33                    [Ar]4s2 3d10 4p4               2.55         190.0
# 34                    [Ar]4s2 3d10 4p5               2.96         183.0
# ..                                 ...                ...           ...
# 113  [Rn]7s2 7p2 5f14 6d10 (predicted)                NaN         180.0
# 114  [Rn]7s2 7p3 5f14 6d10 (predicted)                NaN         187.0
# 115  [Rn]7s2 7p4 5f14 6d10 (predicted)                NaN         183.0
# 116  [Rn]7s2 7p5 5f14 6d10 (predicted)                NaN         138.0
# 117  [Rn]7s2 7p6 5f14 6d10 (predicted)                NaN           NaN
#
#      IonizationEnergy  ElectronAffinity OxidationStates  \
# 30              5.999             0.300              +3
# 31              7.900             1.350          +4, +2
# 32              9.815             0.810      +5, +3, -3
# 33              9.752             2.021      +6, +4, -2
# 34             11.814             3.365      +5, +1, -1
# ..                ...               ...             ...
# 113               NaN               NaN             NaN
# 114               NaN               NaN             NaN
# 115               NaN               NaN             NaN
# 116               NaN               NaN             NaN
# 117               NaN               NaN             NaN
#
#               StandardState  MeltingPoint  BoilingPoint  Density  \
# 30                    Solid        302.91       2477.00    5.910
# 31                    Solid       1211.40       3106.00    5.323
# 32                    Solid       1090.00        887.00    5.776
# 33                    Solid        493.65        958.00    4.809
# 34                   Liquid        265.95        331.95    3.110
# ..                      ...           ...           ...      ...
# 113  Expected to be a Solid           NaN           NaN      NaN
# 114  Expected to be a Solid           NaN           NaN      NaN
# 115  Expected to be a Solid           NaN           NaN      NaN
# 116  Expected to be a Solid           NaN           NaN      NaN
# 117    Expected to be a Gas           NaN           NaN      NaN
#
#                 GroupBlock YearDiscovered
# 30   Post-transition metal           1875
# 31               Metalloid           1886
# 32               Metalloid        Ancient
# 33                Nonmetal           1817
# 34                 Halogen           1826
# ..                     ...            ...
# 113  Post-transition metal           1998
# 114  Post-transition metal           2003
# 115  Post-transition metal           2000
# 116                Halogen           2010
# 117              Noble gas           2006
#
# [88 rows x 17 columns]
#              Name  AtomicRadius  MeltingPoint
# 50       Antimony         206.0        903.78
# 52         Iodine         198.0        386.85
# 54         Cesium         343.0        301.59
# 56      Lanthanum         240.0       1191.00
# 58   Praseodymium         239.0       1204.00
# 60     Promethium         236.0       1315.00
# 62       Europium         233.0       1095.00
# 64        Terbium         221.0       1629.00
# 66        Holmium         216.0       1747.00
# 68        Thulium         227.0       1818.00
# 70       Lutetium         221.0       1936.00
# 72       Tantalum         217.0       3290.00
# 74        Rhenium         217.0       3459.00
# 76        Iridium         202.0       2719.00
# 78           Gold         166.0       1337.33
# 80       Thallium         196.0        577.00
# 82        Bismuth         207.0        544.55
# 84       Astatine         202.0        575.00
# 86       Francium         348.0        300.00
# 88       Actinium         260.0       1324.00
# 90   Protactinium         243.0       1845.00
# 92      Neptunium         221.0        917.00
# 94      Americium         244.0       1449.00
# 96      Berkelium         244.0       1323.00
# 98    Einsteinium         245.0       1133.00
# 100   Mendelevium           NaN       1100.00
# 102    Lawrencium           NaN       1900.00
# 104       Dubnium         139.0           NaN
# 106       Bohrium         128.0           NaN
# 108    Meitnerium         128.0           NaN
# 110   Roentgenium         138.0           NaN
# 112      Nihonium         170.0           NaN
# 114     Moscovium         187.0           NaN
# 116    Tennessine         138.0           NaN

# %% [markdown]
# ### Accessing information by name
# Indices in pandas can either be identified using numbers (as in the row number, similar to numpy arrays), or by name using column names and index names.
#
# #### Accessing columns of data
#
# Unless otherwise specified in the read_csv command, pandas will use the first row of the file as column names. You can use these column names to access data in a particular column.
#
# To see all of the column names, you can type

# %%
periodic_tabel.columns
# Out:
# Index(['AtomicNumber', 'Symbol', 'Name', 'AtomicMass', 'CPKHexColor',
#        'ElectronConfiguration', 'Electronegativity', 'AtomicRadius',
#        'IonizationEnergy', 'ElectronAffinity', 'OxidationStates',
#        'StandardState', 'MeltingPoint', 'BoilingPoint', 'Density',
#        'GroupBlock', 'YearDiscovered'],
#       dtype='object')

# %%
# to access using the column name
periodic_tabel['Name']
# Out:
# 0         Hydrogen
# 1           Helium
# 2          Lithium
# 3        Beryllium
# 4            Boron
#           ...
# 113      Flerovium
# 114      Moscovium
# 115    Livermorium
# 116     Tennessine
# 117      Oganesson
# Name: Name, Length: 118, dtype: object

# %%
# for mutiple columns
periodic_tabel[['Name', 'Symbol']]
# Out:
#             Name Symbol
# 0       Hydrogen      H
# 1         Helium     He
# 2        Lithium     Li
# 3      Beryllium     Be
# 4          Boron      B
# ..           ...    ...
# 113    Flerovium     Fl
# 114    Moscovium     Mc
# 115  Livermorium     Lv
# 116   Tennessine     Ts
# 117    Oganesson     Og
#
# [118 rows x 2 columns]

# %%
# 3 columns
periodic_tabel[['Name', 'AtomicMass', 'StandardState']]
# Out:
#             Name  AtomicMass           StandardState
# 0       Hydrogen    1.008000                     Gas
# 1         Helium    4.002600                     Gas
# 2        Lithium    7.000000                   Solid
# 3      Beryllium    9.012183                   Solid
# 4          Boron   10.810000                   Solid
# ..           ...         ...                     ...
# 113    Flerovium  289.191000  Expected to be a Solid
# 114    Moscovium  290.196000  Expected to be a Solid
# 115  Livermorium  293.205000  Expected to be a Solid
# 116   Tennessine  294.211000  Expected to be a Solid
# 117    Oganesson  294.214000    Expected to be a Gas
#
# [118 rows x 3 columns]

# %% [markdown]
# #### Accessing rows and columns by name
#
# We have already discussed column names, but what about row names? By default, the names of the rows are the same as the numbers. You may have noticed that when you are printing your dataframes, there is an extra first column of numbers going from 0 to 118. These are the row names. Unless otherwise specified in the read_csv command, the row names will default to the row number.
#
# To access rows using the row name, use the .loc method. Currently our row names and numbers are the same, so this does not look any different than using iloc if only one index is specified.

# %%
periodic_tabel.loc[35] # only row numbers
# Out:
# AtomicNumber                           36
# Symbol                                 Kr
# Name                              Krypton
# AtomicMass                           83.8
# CPKHexColor                        5CB8D1
# ElectronConfiguration    [Ar]4s2 3d10 4p6
# Electronegativity                     3.0
# AtomicRadius                        202.0
# IonizationEnergy                     14.0
# ElectronAffinity                      NaN
# OxidationStates                         0
# StandardState                         Gas
# MeltingPoint                       115.79
# BoilingPoint                       119.93
# Density                          0.003733
# GroupBlock                      Noble gas
# YearDiscovered                       1898
# Name: 35, dtype: object

# %%
# you can also use cloumn name insted of number with loc
periodic_tabel.loc[35, 'YearDiscovered']
# Out:
# '1898'

# %% [markdown]
# Let’s see what happens when we change our index to one of our columns, so that we can use loc to access data by name. Imagine that we wanted to be able to access rows in our DataFrame using the element symbol. We will use the command set_index to do this.

# %%
periodic_tabel.set_index('Symbol')
# Out:
#         AtomicNumber         Name  AtomicMass CPKHexColor  \
# Symbol
# H                  1     Hydrogen    1.008000      FFFFFF
# He                 2       Helium    4.002600      D9FFFF
# Li                 3      Lithium    7.000000      CC80FF
# Be                 4    Beryllium    9.012183      C2FF00
# B                  5        Boron   10.810000      FFB5B5
# ...              ...          ...         ...         ...
# Fl               114    Flerovium  289.191000         NaN
# Mc               115    Moscovium  290.196000         NaN
# Lv               116  Livermorium  293.205000         NaN
# Ts               117   Tennessine  294.211000         NaN
# Og               118    Oganesson  294.214000         NaN
#
#                     ElectronConfiguration  Electronegativity  AtomicRadius  \
# Symbol
# H                                     1s1               2.20         120.0
# He                                    1s2                NaN         140.0
# Li                                [He]2s1               0.98         182.0
# Be                                [He]2s2               1.57         153.0
# B                             [He]2s2 2p1               2.04         192.0
# ...                                   ...                ...           ...
# Fl      [Rn]7s2 7p2 5f14 6d10 (predicted)                NaN         180.0
# Mc      [Rn]7s2 7p3 5f14 6d10 (predicted)                NaN         187.0
# Lv      [Rn]7s2 7p4 5f14 6d10 (predicted)                NaN         183.0
# Ts      [Rn]7s2 7p5 5f14 6d10 (predicted)                NaN         138.0
# Og      [Rn]7s2 7p6 5f14 6d10 (predicted)                NaN           NaN
#
#         IonizationEnergy  ElectronAffinity OxidationStates  \
# Symbol
# H                 13.598             0.754          +1, -1
# He                24.587               NaN               0
# Li                 5.392             0.618              +1
# Be                 9.323               NaN              +2
# B                  8.298             0.277              +3
# ...                  ...               ...             ...
# Fl                   NaN               NaN             NaN
# Mc                   NaN               NaN             NaN
# Lv                   NaN               NaN             NaN
# Ts                   NaN               NaN             NaN
# Og                   NaN               NaN             NaN
#
#                  StandardState  MeltingPoint  BoilingPoint   Density  \
# Symbol
# H                          Gas         13.81         20.28  0.000090
# He                         Gas          0.95          4.22  0.000179
# Li                       Solid        453.65       1615.00  0.534000
# Be                       Solid       1560.00       2744.00  1.850000
# B                        Solid       2348.00       4273.00  2.370000
# ...                        ...           ...           ...       ...
# Fl      Expected to be a Solid           NaN           NaN       NaN
# Mc      Expected to be a Solid           NaN           NaN       NaN
# Lv      Expected to be a Solid           NaN           NaN       NaN
# Ts      Expected to be a Solid           NaN           NaN       NaN
# Og        Expected to be a Gas           NaN           NaN       NaN
#
#                    GroupBlock YearDiscovered
# Symbol
# H                    Nonmetal           1766
# He                  Noble gas           1868
# Li               Alkali metal           1817
# Be       Alkaline earth metal           1798
# B                   Metalloid           1808
# ...                       ...            ...
# Fl      Post-transition metal           1998
# Mc      Post-transition metal           2003
# Lv      Post-transition metal           2000
# Ts                    Halogen           2010
# Og                  Noble gas           2006
#
# [118 rows x 16 columns]

# %% [markdown]
# This will print your new DataFrame to the screen. You should notice that now the left most column is named ‘Symbol’ and lists the symbols for each element. Let’s try accessing Kr using loc.

# %%
periodic_tabel.loc['Kr']

# %% [markdown]
# It didn’t work! Why? Examine periodic_data again. The index is the same as before. This is because the .set_index method returns a new copy of the dataframe. If we wish to have later access to this copy, we have two options. We can capture the value in a variable (as in periodic_data_index = periodic_data.set_index('Symbol')).

# %%
periodic_data_symbols = periodic_tabel.set_index('Symbol')

# %%
periodic_data_symbols.loc['Kr']
# Out:
# AtomicNumber                           36
# Name                              Krypton
# AtomicMass                           83.8
# CPKHexColor                        5CB8D1
# ElectronConfiguration    [Ar]4s2 3d10 4p6
# Electronegativity                     3.0
# AtomicRadius                        202.0
# IonizationEnergy                     14.0
# ElectronAffinity                      NaN
# OxidationStates                         0
# StandardState                         Gas
# MeltingPoint                       115.79
# BoilingPoint                       119.93
# Density                          0.003733
# GroupBlock                      Noble gas
# YearDiscovered                       1898
# Name: Kr, dtype: object

# %% [markdown]
# This lists all the information for the entry. Note the bottom, where it says Name: Kr, dtype: object. Kr is what we used for the index.
#
# You can use row, column indexing with both the loc and iloc command. For example, to get the boiling point of Kr, you could use

# %%
periodic_data_symbols.loc['Kr','BoilingPoint']
# Out:
# 119.93

# %%
# same as but less convenient
periodic_data_symbols.iloc[35,12]
# Out:
# 119.93

# %%
# or, you could have combined ways to access data.
# accessing the column name then the row
periodic_data_symbols['BoilingPoint'].loc['Kr']
# Out:
# 119.93

# %%
'''How would you access each of the following:
The electron configuration of Boron.
The atomic radius of the element on row 115.
The value in cell (50, 5)'''

# The electron configuration of Boron
print('B:', periodic_data_symbols.loc['B', 'ElectronConfiguration'])

# The atomic radius of the element on row 115
print('r of element on row 115:', periodic_data_symbols['AtomicRadius'].iloc[115])

# value in cell (50, 5)
print('value in cell in (50, 5):', periodic_data_symbols.iloc[50, 5])
# Out:
# B: [He]2s2 2p1
# r of element on row 115: 183.0
# value in cell in (50, 5): 2.05

# %% [markdown]
# #### Another option for setting the index
#
# Instead of making a new variable (periodic_data_symbols), we might have chose to overwrite our existing dataframe. In pandas, you can do that by adding an additional argument to your set_index function.
#
# We can use the keyword argument inplace=True. When we use this argument, pandas will overwrite the original DataFrame. Always look for this argument in pandas functions.

# %%
periodic_tabel.set_index('Symbol', inplace = True)

# If you wanted to change your index back to numbers, you would use the command reset_index

periodic_tabel.reset_index(inplace=True)

# %% [markdown]
# This is a very important command. If you set another index without resetting the index, the Symbol column will be lost. This comman reverts it back to a column.

# %% [markdown]
# ### Broadcating and such
# Like NumPy arrays, pandas also takes advantage of broadcasting. You can add scalars or vectors to data easily.
#
# We could calculate the melting point in celsius

# %%
periodic_data_symbols['MeltingPoint'] - 273.15
# Out:
# Symbol
# H     -259.34
# He    -272.20
# Li     180.50
# Be    1286.85
# B     2074.85
#        ...
# Fl        NaN
# Mc        NaN
# Lv        NaN
# Ts        NaN
# Og        NaN
# Name: MeltingPoint, Length: 118, dtype: float64

# %% [markdown]
# If you would like to capture this in a new DataFrame column, you can do so easily by putting the new column name in square brackets following the DataFrame name.

# %%
periodic_data_symbols['MeltingPointC'] = periodic_data_symbols['MeltingPoint'] - 273.15

# %%
periodic_data_symbols['BoilingPointC'] = periodic_data_symbols['BoilingPoint'] - 273.15

# %% [markdown]
# But what if we wanted to use a function instead of a scalar? Imagine you had written a function to convert temperatures in Kelvin to Fahrenheit.

# %%
def k_to_f(k_temp):
    f_temp = (k_temp - 273.15) * (9/5) + 32
    return f_temp

#k_to_f(periodic_data_symbols['BoilingPoint'])
# Out:
# Symbol
# H     -423.166
# He    -452.074
# Li    2447.330
# Be    4479.530
# B     7231.730
#         ...
# Fl         NaN
# Mc         NaN
# Lv         NaN
# Ts         NaN
# Og         NaN
# Name: BoilingPoint, Length: 118, dtype: float64

# %% [markdown]
# If you wanted to apply this function to every row, your first instinct might be to write a for loop. This would work, but pandas has a built in method called apply to easily allow you to do this.
#
# When you call the apply method, you give it a function name which you would like to apply to every element of whatever you are using it on.

# %%
# K to F
periodic_data_symbols['BoilingPoint'].apply(k_to_f)
# Out:
# Symbol
# H     -423.166
# He    -452.074
# Li    2447.330
# Be    4479.530
# B     7231.730
#         ...
# Fl         NaN
# Mc         NaN
# Lv         NaN
# Ts         NaN
# Og         NaN
# Name: BoilingPoint, Length: 118, dtype: float64

# %%
# to save it as a new column
periodic_data_symbols['BoilingPointF'] = periodic_data_symbols['BoilingPoint'].apply(k_to_f)

# %%
periodic_data_symbols['MeltingPointF'] = periodic_data_symbols['MeltingPoint'].apply(k_to_f)

# %% [markdown]
# ### Saving your new Dataframe
# If you wanted to save your data as a csv, you could do it using the command to_csv

# %%
periodic_data_symbols.to_csv('periodic_data_processed.csv')

# %% [markdown]
# ### Filtering and sorting your DataFrame

# %% [markdown]
# Use .query to filter data
#
# You can use the function .query to query your data. You type a logical expression in a string inside of the function.
#
# For example, to find all of the elements with a melting point greater than 298,

# %%
periodic_data = periodic_tabel.set_index('Symbol') # new varibel to play with

periodic_data.query('MeltingPoint > 298')
# Out:
#         AtomicNumber         Name  AtomicMass CPKHexColor  \
# Symbol
# Li                 3      Lithium    7.000000      CC80FF
# Be                 4    Beryllium    9.012183      C2FF00
# B                  5        Boron   10.810000      FFB5B5
# C                  6       Carbon   12.011000      909090
# Na                11       Sodium   22.989769      AB5CF2
# ...              ...          ...         ...         ...
# Es                99  Einsteinium  252.083000      B31FD4
# Fm               100      Fermium  257.095110      B31FBA
# Md               101  Mendelevium  258.098430      B30DA6
# No               102     Nobelium  259.101000      BD0D87
# Lr               103   Lawrencium  262.110000      C70066
#
#        ElectronConfiguration  Electronegativity  AtomicRadius  \
# Symbol
# Li                   [He]2s1               0.98         182.0
# Be                   [He]2s2               1.57         153.0
# B                [He]2s2 2p1               2.04         192.0
# C                [He]2s2 2p2               2.55         170.0
# Na                   [Ne]3s1               0.93         227.0
# ...                      ...                ...           ...
# Es              [Rn]7s2 5f11               1.30         245.0
# Fm             [Rn] 5f12 7s2               1.30           NaN
# Md              [Rn]7s2 5f13               1.30           NaN
# No              [Rn]7s2 5f14               1.30           NaN
# Lr          [Rn]7s2 5f14 6d1               1.30           NaN
#
#         IonizationEnergy  ElectronAffinity OxidationStates StandardState  \
# Symbol
# Li                 5.392             0.618              +1         Solid
# Be                 9.323               NaN              +2         Solid
# B                  8.298             0.277              +3         Solid
# C                 11.260             1.263      +4, +2, -4         Solid
# Na                 5.139             0.548              +1         Solid
# ...                  ...               ...             ...           ...
# Es                 6.420               NaN              +3         Solid
# Fm                 6.500               NaN              +3         Solid
# Md                 6.580               NaN          +3, +2         Solid
# No                 6.650               NaN          +3, +2         Solid
# Lr                   NaN               NaN              +3         Solid
#
#         MeltingPoint  BoilingPoint  Density            GroupBlock  \
# Symbol
# Li            453.65        1615.0    0.534          Alkali metal
# Be           1560.00        2744.0    1.850  Alkaline earth metal
# B            2348.00        4273.0    2.370             Metalloid
# C            3823.00        4098.0    2.267              Nonmetal
# Na            370.95        1156.0    0.970          Alkali metal
# ...              ...           ...      ...                   ...
# Es           1133.00           NaN      NaN              Actinide
# Fm           1800.00           NaN      NaN              Actinide
# Md           1100.00           NaN      NaN              Actinide
# No           1100.00           NaN      NaN              Actinide
# Lr           1900.00           NaN      NaN              Actinide
#
#        YearDiscovered
# Symbol
# Li               1817
# Be               1798
# B                1808
# C             Ancient
# Na               1807
# ...               ...
# Es               1952
# Fm               1952
# Md               1955
# No               1957
# Lr               1961
#
# [90 rows x 16 columns]

# %%
# two conditions
periodic_data.query('MeltingPoint > 298 and BoilingPoint < 500')
# Out:
#         AtomicNumber    Name  AtomicMass CPKHexColor ElectronConfiguration  \
# Symbol
# I                 53  Iodine    126.9045      940094      [Kr]5s2 4d10 5p5
#
#         Electronegativity  AtomicRadius  IonizationEnergy  ElectronAffinity  \
# Symbol
# I                    2.66         198.0            10.451             3.059
#
#        OxidationStates StandardState  MeltingPoint  BoilingPoint  Density  \
# Symbol
# I       +7, +5, +1, -1         Solid        386.85        457.55     4.93
#
#        GroupBlock YearDiscovered
# Symbol
# I         Halogen           1811

# %%
# compare two columns
periodic_data.query('MeltingPoint > BoilingPoint')
# Out:
#         AtomicNumber     Name  AtomicMass CPKHexColor ElectronConfiguration  \
# Symbol
# As                33  Arsenic    74.92159      BD80E3      [Ar]4s2 3d10 4p3
#
#         Electronegativity  AtomicRadius  IonizationEnergy  ElectronAffinity  \
# Symbol
# As                   2.18         185.0             9.815              0.81
#
#        OxidationStates StandardState  MeltingPoint  BoilingPoint  Density  \
# Symbol
# As          +5, +3, -3         Solid        1090.0         887.0    5.776
#
#        GroupBlock YearDiscovered
# Symbol
# As      Metalloid        Ancient

# %% [markdown]
# ### Sorting data
# Use .sort_values to sort data
#
# To sort data, you can use the sort_values function.
#
# periodic_data.sort_values(by='MeltingPoint')
#
# This will sort the rows (axis=0) by the values in the ‘MeltingPoint’ column. If you are familiar with Excel, this is similar to how spreadsheets are sorted if you sort based on one of the columns. This sort will return a DataFrame where elements with the lowest melting point are listed first.
#
# It is also possible to columns based on values in a row. However, they all have to be the same type (numeric or string).
#
# For example,

# %%
periodic_data.sort_values(by='MeltingPoint')

numeric_data = periodic_data [['AtomicNumber', 'BoilingPoint','AtomicMass', 'MeltingPoint']].copy()
numeric_data.head()
# Out:
#         AtomicNumber  BoilingPoint  AtomicMass  MeltingPoint
# Symbol
# H                  1         20.28    1.008000         13.81
# He                 2          4.22    4.002600          0.95
# Li                 3       1615.00    7.000000        453.65
# Be                 4       2744.00    9.012183       1560.00
# B                  5       4273.00   10.810000       2348.00

# %%
numeric_data.sort_values(by='Au', axis=1)
# notice how the columns order changes
# Out:
#         AtomicNumber  AtomicMass  MeltingPoint  BoilingPoint
# Symbol
# H                  1    1.008000         13.81         20.28
# He                 2    4.002600          0.95          4.22
# Li                 3    7.000000        453.65       1615.00
# Be                 4    9.012183       1560.00       2744.00
# B                  5   10.810000       2348.00       4273.00
# ...              ...         ...           ...           ...
# Fl               114  289.191000           NaN           NaN
# Mc               115  290.196000           NaN           NaN
# Lv               116  293.205000           NaN           NaN
# Ts               117  294.211000           NaN           NaN
# Og               118  294.214000           NaN           NaN
#
# [118 rows x 4 columns]

# %% [markdown]
# ### Group data
#
# Use .groupby to group data
#
# You can also group values in a DataFrame using the groupby function.
#
# grouped_data = periodic_data.groupby(by='StandardState')
#
# Here, we are grouping the DataFrame based on values in the column ‘ExpectedState’.
#
# We can see the groups which have been created by using .groups

# %%
grouped_data = periodic_data.groupby(by='StandardState')

# %%
grouped_data.groups
# Out:
# {'Expected to be a Gas': ['Og'], 'Expected to be a Solid': ['Ds', 'Rg', 'Cn', 'Nh', 'Fl', 'Mc', 'Lv', 'Ts'], 'Gas': ['H', 'He', 'N', 'O', 'F', 'Ne', 'Cl', 'Ar', 'Kr', 'Xe', 'Rn'], 'Liquid': ['Br', 'Hg'], 'Solid': ['Li', 'Be', 'B', 'C', 'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Te', 'I', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Tl', 'Pb', 'Bi', 'Po', 'At', 'Fr', 'Ra', 'Ac', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Rf', 'Db', 'Sg', 'Bh', 'Hs', 'Mt']}

# %% [markdown]
# We can then retrieve any group by name. For example, to get the data associated with gases,
#
# grouped_data.get_group('Gas')
#
# This will return a pandas DataFrame where all of the elements returned have the expected state of Gas.
#
# Grouping is particularly useful for calculating statistics about data that fits a particular criteria.

# %%
grouped_data.get_group('Gas')
# Out:
#         AtomicNumber      Name  AtomicMass CPKHexColor  ElectronConfiguration  \
# Symbol
# H                  1  Hydrogen    1.008000      FFFFFF                    1s1
# He                 2    Helium    4.002600      D9FFFF                    1s2
# N                  7  Nitrogen   14.007000      3050F8           [He] 2s2 2p3
# O                  8    Oxygen   15.999000      FF0D0D            [He]2s2 2p4
# F                  9  Fluorine   18.998403      90E050            [He]2s2 2p5
# Ne                10      Neon   20.180000      B3E3F5            [He]2s2 2p6
# Cl                17  Chlorine   35.450000      1FF01F            [Ne]3s2 3p5
# Ar                18     Argon   39.900000      80D1E3            [Ne]3s2 3p6
# Kr                36   Krypton   83.800000      5CB8D1       [Ar]4s2 3d10 4p6
# Xe                54     Xenon  131.290000      429EB0       [Kr]5s2 4d10 5p6
# Rn                86     Radon  222.017580      428296  [Xe]6s2 4f14 5d10 6p6
#
#         Electronegativity  AtomicRadius  IonizationEnergy  ElectronAffinity  \
# Symbol
# H                    2.20         120.0            13.598             0.754
# He                    NaN         140.0            24.587               NaN
# N                    3.04         155.0            14.534               NaN
# O                    3.44         152.0            13.618             1.461
# F                    3.98         135.0            17.423             3.339
# Ne                    NaN         154.0            21.565               NaN
# Cl                   3.16         175.0            12.968             3.617
# Ar                    NaN         188.0            15.760               NaN
# Kr                   3.00         202.0            14.000               NaN
# Xe                   2.60         216.0            12.130               NaN
# Rn                    NaN         220.0            10.745               NaN
#
#                        OxidationStates StandardState  MeltingPoint  \
# Symbol
# H                               +1, -1           Gas         13.81
# He                                   0           Gas          0.95
# N       +5, +4, +3, +2, +1, -1, -2, -3           Gas         63.15
# O                                   -2           Gas         54.36
# F                                   -1           Gas         53.53
# Ne                                   0           Gas         24.56
# Cl                      +7, +5, +1, -1           Gas        171.65
# Ar                                   0           Gas         83.80
# Kr                                   0           Gas        115.79
# Xe                                   0           Gas        161.36
# Rn                                   0           Gas        202.00
#
#         BoilingPoint   Density GroupBlock YearDiscovered
# Symbol
# H              20.28  0.000090   Nonmetal           1766
# He              4.22  0.000179  Noble gas           1868
# N              77.36  0.001251   Nonmetal           1772
# O              90.20  0.001429   Nonmetal           1774
# F              85.03  0.001696    Halogen           1670
# Ne             27.07  0.000900  Noble gas           1898
# Cl            239.11  0.003214    Halogen           1774
# Ar             87.30  0.001784  Noble gas           1894
# Kr            119.93  0.003733  Noble gas           1898
# Xe            165.03  0.005887  Noble gas           1898
# Rn            211.45  0.009730  Noble gas           1900

# %%
for group, data in grouped_data:
    if group == 'Expected to be a Gas' or group == 'Expected to be a Solid': continue
    print(group, data['BoilingPoint'].mean(), data['BoilingPoint'].std())
# Out:
# Gas 102.45272727272727 76.27220858096467
# Liquid 480.91499999999996 210.6683233189081
# Solid 2922.236875 1361.7433032823824

# %% [markdown]
# ### Built-in Plotting
#
# Looking at our data above, we notice very high standard deviations for some of the groups. One way we might examine this visually by looking at a histogram plot.
#
# Pandas DataFrames have several built-in plotting functions, one of which is .hist. If we call this function on just a DataFrame, it will make a histogram for each column of data.
#
# In our case, we are interested in the histogram for each group we have created.
#
# We could make histograms for each of our groups by adding this command into our for loop.

# %%
for group, data in grouped_data:
    if group == 'Expected to be a Gas' or group == 'Expected to be a Solid': continue
    print(group, data['BoilingPoint'].mean(), data['BoilingPoint'].std())
    group,data.hist(column='BoilingPoint')
# Out:
# Gas 102.45272727272727 76.27220858096467
# Liquid 480.91499999999996 210.6683233189081
# Solid 2922.236875 1361.7433032823824

# %%
# add a title and sav img

import matplotlib.pyplot as plt
for group, data in grouped_data:
    if group == 'Expected to be a Gas' or group == 'Expected to be a Solid': continue
    print(group, data['BoilingPoint'].mean(), data['BoilingPoint'].std())
    data.hist(column='BoilingPoint')
    plt.title(group)
    plt.savefig(group+'_bp_hist.png', dpi=300)
# Out:
# Gas 102.45272727272727 76.27220858096467
# Liquid 480.91499999999996 210.6683233189081
# Solid 2922.236875 1361.7433032823824

# %%
# to get all histograms in the same figure 

periodic_data.hist(column='BoilingPoint', by='StandardState', figsize= (10,10))
plt.savefig('All_bp_hist.png', dpi=600)

# %%
# Another plotting option you might have chosen was a boxplot

periodic_data.boxplot(column='BoilingPoint', by='StandardState', rot=90)
plt.suptitle('') # remove suptitle
plt.savefig('boxplot_bp.png',dpi=300)

# %% [markdown]
# ## Key Points
# Pandas stores data in a structure called a dataframe
#
# Pandas can read data that has lots of different data types.
#
# You can easily get statistics from a dataframe by using methods like df.describe()
