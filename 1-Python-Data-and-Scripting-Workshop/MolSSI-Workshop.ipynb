# %% [markdown]
# # MolSSI Workshop
# ## Introduction
#
# This lesson covers Python basics like variable creation and assignment and using the Jupyter notebook

# %%
x=3+7

# %%
x=3+7

# %%
deltaH = -541.5   #kJ/mole
deltaS =  10.4     #kJ/(mole K)
temp = 298      #Kelvin
deltaG = deltaH - temp * deltaS
print(round(deltaG),'kJ/mole')
deltaG_joules=deltaG * 1000
print(round(deltaG_joules),'J/mole')
# Out:
# -3641 kJ/mole
# -3640700 J/mole

# %%
#I can assign all these variables at once
deltaH, deltaS, temp = -541.5, 10.4, 298
deltaG = deltaH - temp * deltaS
print(deltaG)
# Out:
# -3640.7000000000003

# %%
# This is a list
energy_kcal = [-13.4, -2.7, 5.4, 42.1]
# I can determine its length
energy_length = len(energy_kcal)

# print the list length
print('The length of this list is', energy_length)
# Out:
# The length of this list is 4

# %%
# Convert the second list element to kilojoules.
energy_kilojoules = energy_kcal[1] * 4.184
print(energy_kilojoules)
# Out:
# -11.296800000000001

# %%
short_list = energy_kcal[0:2]
print(short_list)
# Out:
# [-13.4, -2.7]

# %%
for number in energy_kcal:
    kJ = number * 4.184
    print(round(kJ),'kJ/mol')
# Out:
# -56 kJ/mol
# -11 kJ/mol
# 23 kJ/mol
# 176 kJ/mol

# %%
energy_kJ=[]
for number in energy_kcal:
    kJ = number * 4.184
    energy_kJ.append(kJ)

print(energy_kJ)
# Out:
# [-56.0656, -11.296800000000001, 22.593600000000002, 176.1464]

# %%
negative_energy_kJ = []

for number in energy_kJ:
    if number < 0:
        negative_energy_kJ.append(number)

print(negative_energy_kJ)
# Out:
# [-56.0656, -11.296800000000001]

# %%
#ex
number_list=list()
data_list = ['-12.5', 14.4, 8.1, '42']
for i in data_list:
    number_list.append(float(i))
print(number_list)
# Out:
# [-12.5, 14.4, 8.1, 42.0]

# %%
ls data
# Out:
# 03_Prod.mdout              distance_data_headers.csv
# 03_Prodd.mdout             outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz

# %%
pwd
# Out:
# '/Users/Turk/Desktop/projects/MolSSI-workshops/Python-Data-and-Scripting-Workshop'

# %%
import os

ethanol_file=os.path.join('data','outfiles','ethanol.out')
print(ethanol_file,'\n',os.path.abspath(ethanol_file))
# Out:
# data/outfiles/ethanol.out
#  /Users/Turk/Desktop/projects/MolSSI-workshops/Python-Data-and-Scripting-Workshop/data/outfiles/ethanol.out

# %%
outfile=open(ethanol_file,'r')
data=outfile.readlines()
#print(type(data),data[:10])
outfile.close()
count=0
for line in data:
    count +=1
print('number of lines=',count) 
print('an easier and betetr way is to use len(data) since it is a list','\n','number of lines=',len(data))
# Out:
# number of lines= 270
# an easier and betetr way is to use len(data) since it is a list
#  number of lines= 270

# %%
#another way, so you don't have to close the file
with open(ethanol_file,'r') as outfile:
    data=outfile.readlines()
#print(type(data),data)

# %%
for line in data:
    #line=line.rstrip()
    if 'Final Energy' in line:
        x=line.split()
        energy=float(x[-1])
        #print(x)
        print(energy, energy+50)
# Out:
# -154.09130176573018 -104.09130176573018

# %%
sapt_file=os.path.join('data','sapt.out')
#print(sapt_file)
outfile_1=open(sapt_file,'r')
data_1=outfile_1.readlines()
outfile_1.close()
sum=0
for line in data_1:
    #print(line)
    if 'Electrostatics  ' in line or 'Exchange  ' in line or 'Induction  ' in line or 'Dispersion  ' in line:
        line=line.split()
        Electo=float(line[3])
        #print(Electo)
        print(line[0]+' : ' + line[3] +' kcal/mol')
        sum= sum+Electo
        
print('Total Energy', sum, 'kcal/mol')
'''
their solution; mine is better and I had to add sum to theirs and comment out the second to last line
important_lines = []
energies = []

with open('SAPT.out','r') as saptout:
    for line in saptout:
        if 'Electrostatics    ' in line:
            electro_line = line
            important_lines.append(electro_line)
        if 'Exchange       ' in line:
            exchange_line = line
            important_lines.append(exchange_line)
        if 'Induction      ' in line:
            induction_line = line
            important_lines.append(induction_line)
        if 'Dispersion     ' in line:
            dispersion_line = line
            important_lines.append(dispersion_line)

# print(important_lines)
sum=0
for line in important_lines:
    words = line.split()
    # print(words)
    energy_type = words[0]
    energy_kcal = float(words[3])
    energies.append(energy_kcal)
    print('{} : {} kcal/mol'.format(energy_type, energy_kcal))
    sum += energy_kcal

#total_energy = sum(energies) 
print('Total Energy : {} kcal/mol'.format(sum))

'''
# Out:
# Electrostatics : -2.25850118 kcal/mol
# Exchange : 2.27730198 kcal/mol
# Induction : -0.52169330 kcal/mol
# Dispersion : -0.94466770 kcal/mol
# Total Energy -1.4475602000000003 kcal/mol
# ...

# %%
outfile_1=open(sapt_file,'r')
data_1=outfile_1.readlines()
outfile_1.close()
#print(data)

for linenum, line in enumerate(data):
    if 'Center' in line:
        print(linenum)
        print(line)
#print(data[])
print(data[78])
print(data[79])
# Out:
# 77
#        Center              X                  Y                   Z               Mass
#
#     ------------   -----------------  -----------------  -----------------  -----------------
#
#            H          0.278612764252     1.265047047666    -1.274211449480     1.007825032070

# %% [markdown]
# # Processing Multiple Files and Writing Files
#
# ## Processing multiple files

# %%
file_location = os.path.join('data', 'outfiles','*.out')
print(file_location)
# Out:
# data/outfiles/*.out

# %%
import glob as gb
filenames=gb.glob(file_location)
print(filenames)
# Out:
# ['data/outfiles/propanol.out', 'data/outfiles/pentanol.out', 'data/outfiles/decanol.out', 'data/outfiles/methanol.out', 'data/outfiles/octanol.out', 'data/outfiles/ethanol.out', 'data/outfiles/hexanol.out', 'data/outfiles/heptanol.out', 'data/outfiles/butanol.out', 'data/outfiles/nonanol.out']

# %%
print(filenames[0])
file_name=os.path.basename(filenames[0])
print(file_name)
molecule_name=file_name.split('.')
print(molecule_name[0])
# Out:
# data/outfiles/propanol.out
# propanol.out
# propanol

# %%
for i in filenames:
    file_name=os.path.basename(i)
    split_filename=file_name.split('.')
    molecule_name=split_filename[0]
    #print(molecule_name)

# %%
for file in filenames:
    # Get the molecule name
    file_name=os.path.basename(file)
    split_name=file_name.split('.')
    molecule_name=split_name[0]
    
    # Read the data
    outfile=open(file,'r')
    data=outfile.readlines()
    outfile.close()
    
    # Loop through the data
    for line in data:
        if 'Final Energy' in line:
            #print(line)
            word=line.split()
            print(molecule_name+': '+word[-1])
# Out:
# propanol: -193.12836249728798
# pentanol: -271.20138119895074
# decanol: -466.38362414000858
# methanol: -115.04800861868374
# octanol: -388.31108645547431
# ethanol: -154.09130176573018
# hexanol: -310.23853322516328
# heptanol: -349.27397687072676
# butanol: -232.16557983472831
# nonanol: -427.34651800828152

# %% [markdown]
# # Printing to a File

# %%
datafile=open('energies.txt','w+')

for file in filenames:
    # Get the molecule name
    file_name=os.path.basename(file)
    split_name=file_name.split('.')
    molecule_name=split_name[0]
    
    # Read the data
    outfile=open(file,'r')
    data=outfile.readlines()
    outfile.close()
    
    # Loop through the data
    for line in data:
        if 'Final Energy' in line:
            #print(line)
            word=line.split()
            energy=word[-1]
            #print(molecule_name+': '+word[-1])
            datafile.write(F'{molecule_name} {energy}\n')
            #datafile.write(F'For the file {molecule_name} the energy is {energy} in kcal/mole. \n')
datafile.close()

# %% [markdown]
# ## Project Assignment

# %% [markdown]
# In the lesson materials, there is a file called 03_Prod.mdout. This is a file output by the Amber molecular dynamics simulation program.
# If you open the file and look at it, you will see sections which look like this:
#  NSTEP =      100   TIME(PS) =      20.200  TEMP(K) =   296.43  PRESS =  -300.8
#  Etot   =     -4585.1049  EKtot   =      1129.2368  EPtot      =     -5714.3417
#  BOND   =         1.5160  ANGLE   =         6.9846  DIHED      =        11.7108
#  1-4 NB =         4.3175  1-4 EEL =        49.9911  VDWAALS    =       882.6741
#  EELEC  =     -6671.5358  EHBOND  =         0.0000  RESTRAINT  =         0.0000
#  EKCMT  =       583.7810  VIRIAL  =       786.8823  VOLUME     =     31270.0410
#                                                     Density    =         0.6104
#  Ewald error estimate:   0.3214E-03
#  ------------------------------------------------------------------------------
# Your assignment is to parse this file, and write a new file containing a list of the > total energies. Name your file Etot.txt. When you open it, it should look like this:
# -4585.1049
# -4573.5326
# -4548.1223
# -4525.341
# -4542.8995
# -4550.9376
# -4543.8652
# -4570.4109
# -4550.4225
# -4585.2078
# ...
# ... indicates that you will have many more rows. We’ve only shown the first 10 here.
# If you are unsure of where to start with this assignment, check the hint section!

# %%
# open the file after defining the path
file_name=os.path.join('data','03_prod.mdout')
outfile=open(file_name,'r')
data=outfile.readlines()
outfile.close()

# write to a file
datafile=open('03_prod_energies.txt','w+')

#read lines
for line in data:
    if 'Etot  ' in line:
        words=line.split()
        #energy=words[2]
        datafile.write(F'{words[2]} \n')
datafile.close()

# %%
# open the file after defining the path
file_name=os.path('data','03_prod.mdout')
outfile=open(file_name,'r')
data=outfile.readlines()
outfile.close()
f_name=os.path.basename(file_name)
#file_name.split('.')
# write to a file
datafile=open(file_name +'_Etot.txt','w+')

#read lines
for line in data:
    if 'Etot  ' in line:
        words=line.split()
        #energy=words[2]
        if '-' in words[2]:
            datafile.write(F'{words[2]} \n')
datafile.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-69a375c38f68> in <module>
#       1 # open the file after defining the path
# ----> 2 file_name=os.path('data','03_prod.mdout')
#       3 outfile=open(file_name,'r')
#       4 data=outfile.readlines()
#       5 outfile.close()
#
# TypeError: 'module' object is not callable

# %%
f_name=os.path.basename(file_name).split('.')[0]
print(f_name)
# Out:
# 03_prod

# %% [markdown]
# # Working with Tabular Data
# ## Reading in Tabular Data

# %%
import numpy as np
help(np.genfromtxt)
# Out:
# Help on function genfromtxt in module numpy:
#
# genfromtxt(fname, dtype=<class 'float'>, comments='#', delimiter=None, skip_header=0, skip_footer=0, converters=None, missing_values=None, filling_values=None, usecols=None, names=None, excludelist=None, deletechars=" !#$%&'()*+,-./:;<=>?@[\\]^{|}~", replace_space='_', autostrip=False, case_sensitive=True, defaultfmt='f%i', unpack=None, usemask=False, loose=True, invalid_raise=True, max_rows=None, encoding='bytes')
#     Load data from a text file, with missing values handled as specified.
#
#     Each line past the first `skip_header` lines is split at the `delimiter`
#     character, and characters following the `comments` character are discarded.
#
#     Parameters
#     ----------
#     fname : file, str, pathlib.Path, list of str, generator
#         File, filename, list, or generator to read.  If the filename
#         extension is `.gz` or `.bz2`, the file is first decompressed. Note
# ...

# %%
distance_file=os.path.join('data','distance_data_headers.csv')

distances=np.genfromtxt(distance_file,delimiter=',',dtype='unicode')
print(distances)
# Out:
# [['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']
#  ['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %% [markdown]
# ## Manipulating Tabular Data

# %%
headers=distances[0]
print(headers)
# Out:
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']

# %%
data=distances[1:]
print(data)
# Out:
# [['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ['3' '9.0066' '6.0637' '13.0924' '11.3043']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %%
data=data.astype(float)
print(data)
# Out:
# [[1.00000e+00 8.95420e+00 5.80240e+00 1.15478e+01 9.95570e+00]
#  [2.00000e+00 8.61810e+00 6.09420e+00 1.39594e+01 1.16945e+01]
#  [3.00000e+00 9.00660e+00 6.06370e+00 1.30924e+01 1.13043e+01]
#  ...
#  [9.99800e+03 8.66250e+00 7.73060e+00 9.54690e+00 1.03063e+01]
#  [9.99900e+03 9.24560e+00 7.88860e+00 9.81510e+00 1.07564e+01]
#  [1.00000e+04 8.81350e+00 7.91700e+00 9.95170e+00 1.07848e+01]]

# %%
print(data[0,1])
print(data[1,0])
# Out:
# 8.9542
# 2.0

# %%
small_data=data[0:10,0:3]
print(small_data)
# Out:
# [[ 1.      8.9542  5.8024]
#  [ 2.      8.6181  6.0942]
#  [ 3.      9.0066  6.0637]
#  [ 4.      9.2002  6.0227]
#  [ 5.      9.1294  5.9365]
#  [ 6.      9.0462  6.2553]
#  [ 7.      8.8657  5.9186]
#  [ 8.      9.3256  6.2351]
#  [ 9.      9.4184  6.1993]
#  [10.      9.06    6.0478]]

# %%
print(small_data[5,:])
print(small_data[:,1:])
# Out:
# [6.     9.0462 6.2553]
# [[8.9542 5.8024]
#  [8.6181 6.0942]
#  [9.0066 6.0637]
#  [9.2002 6.0227]
#  [9.1294 5.9365]
#  [9.0462 6.2553]
#  [8.8657 5.9186]
#  [9.3256 6.2351]
#  [9.4184 6.1993]
#  [9.06   6.0478]]

# %% [markdown]
# ## Analyzing Tabular Data

# %%
data_average=np.mean(small_data[:,1])
print(small_data[:,1],data_average)
print(headers)
# Out:
# [8.9542 8.6181 9.0066 9.2002 9.1294 9.0462 8.8657 9.3256 9.4184 9.06  ] 9.06244
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']

# %%
thr4_atp=data[:,1]
ave_thr4_atp=np.mean(thr4_atp)
print('average of THR4_ATP=',ave_thr4_atp)
# Out:
# average of THR4_ATP= 10.876950930000001

# %%
num_columns= len(data[0,:]) # first raw with all the columns
print(num_columns)
# Out:
# 5

# %%
for column in range(1,num_columns): # for every column in the range 1 to 5
    set_columns=data[:,column] 
    ave_col=np.mean(set_columns)
    print(F'{headers[column]} : {ave_col}')
# Out:
# THR4_ATP : 10.876950930000001
# THR4_ASP : 7.342344959999999
# TYR6_ATP : 11.209791329999998
# TYR6_ASP : 10.9934435

# %% [markdown]
# ## Geometry Analysis Project

# %%
wat_file_path=os.path.join('data','water.xyz')
wat_data=np.genfromtxt(wat_file_path,skip_header=2,dtype='unicode') # error if you don't skip headers
#print(wat_data)

atoms=wat_data[:,0]
#print(atoms)
coords=wat_data[:,1:]
coords=coords.astype(float)
#print(coords)
#print(len(coords)) =3
for num1 in range(0,3):
    for num2 in range(0,3):
        atom1 = coords[num1]
        atom2 = coords[num2]
        x_distance=atom1[0]-atom2[0] # better to understand method
        #x_distance=coords[num1,0] - coords[num2,0]
        y_distance=coords[num1,1] - coords[num2,1]
        z_distance=coords[num1,2] - coords[num2,2] # 9 values for each distance right?
        bond_length= np.sqrt(x_distance**2+y_distance**2+z_distance**2)
        print(F'{atoms[num1]} to {atoms[num2]} : {bond_length:.3f}')
# Out:
# O to O : 0.000
# O to H1 : 0.969
# O to H2 : 0.969
# H1 to O : 0.969
# H1 to H1 : 0.000
# H1 to H2 : 1.527
# H2 to O : 0.969
# H2 to H1 : 1.527
# H2 to H2 : 0.000

# %%
# different one
wat_file_path=os.path.join('data','water.xyz')
BLfile=open('bond_lengths.txt','w+')
wat_data=open(wat_file_path,'r')
wat_data=wat_data.readlines()
num_atoms=int(wat_data[0]) #=3 atoms
wat_data=wat_data[2:]

atoms=[]
coords=[]

for atom in wat_data:
    atom_data=atom.split()
    #print(atom_data)
    atoms.append(atom_data[0])
#print(atoms)
    x, y, z= atom_data[1],atom_data[2],atom_data[3]
    coords.append([float(x),float(y),float(z)])
#print(coords)
for num1 in range(0,3):
    for num2 in range(0,3):
        atom1 = coords[num1]
        atom2 = coords[num2]
        if num1<num2: # this line to remove duplicates
            x_distance=atom1[0]-atom2[0]
            y_distance=atom1[1]-atom2[1]
            z_distance=atom1[2]-atom2[2]
            bond_length= np.sqrt(x_distance**2+y_distance**2+z_distance**2)
            if bond_length <= 1.5 and bond_length != 0:
            
                #print(F'{atoms[num1]} to {atoms[num2]} : {bond_length:.3f}')
                BLfile.write(F'{atoms[num1]} to {atoms[num2]} : {bond_length:.3f} \n')
BLfile.close()

# %% [markdown]
# # Plotting and Data Visualization
# ## Plotting Data

# %%
# same as before 
import os
import numpy

distance_file = os.path.join('data', 'distance_data_headers.csv')
distances = numpy.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')
headers = distances[0]
data = distances[1:]
data = data.astype(float)
#print(data)

# %%
import matplotlib.pyplot as plt
plt.figure() # make a new figure
plt.plot(data[:,1]) # plot

# %% [markdown]
# ## Labeling plots and saving figures

# %%
sample= headers[1] #THR4_ATP

plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
fig_1=plt.plot(data[:,1], label=sample)
plt.legend()
plt.plot()

plt.savefig(F'{sample}.png')

# %% [markdown]
# ## Increasing image resolution

# %%
sample= headers[1] #THR4_ATP

plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
fig_1=plt.plot(data[:,1], label=sample)
plt.legend()
plt.plot()

plt.savefig(F'{sample}.png',dpi=600)

# %% [markdown]
# ## Plotting more than one set of data

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')

fig_1=plt.plot(data[:,1], label=headers[1])
fig_2=plt.plot(data[:,2], label=headers[2])
#fig_3=plt.plot(data[:,3], label=headers[3])
plt.legend()
plt.plot()

plt.savefig('two_samples.png',dpi=300)

# %%
for col in range(1, len(headers)):
    fig = plt.plot(data[:,col], label=headers[col])
    plt.legend()

plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.savefig('all_samples.png',dpi=600)

# %%
# plot each one indvidually
for col in range(1, len(headers)):
    plt.figure()
    plt.plot(data[:,col],label=headers[col])

    plt.xlabel('Simulation Frame')
    plt.ylabel('Distance (angstrom)')
    plt.legend()
    plt.savefig(f'{headers[col]}.png',dpi=300)

# %% [markdown]
# ## Normalizing your axes across plots

# %%
data_min=np.min(data[:,1:])*.9 # min of the whole data, the first column is just 1 2 3 4 so we skip it
data_max=np.max(data[:,1:])*1.1 # max of the whole data
# notice we scaled the data to give them breathing room

# %%
# plot each one indvidually with min and max data for y
for col in range(1, len(headers)):
    plt.figure()
    plt.plot(data[:,col],label=headers[col])

    plt.xlabel('Simulation Frame')
    plt.ylabel('Distance (angstrom)')
    plt.legend()
    #add the limits
    plt.ylim(data_min,data_max)
    plt.savefig(f'{headers[col]}.png',dpi=300)

# %% [markdown]
# ## Plotting with x and y

# %%
plt.figure()
plt.plot(data[:,0], data[:,1])
# the same exact thing but we spesfied x this time 
# if you don't which is what we did before, then it will be the count which is 1 2 3 4 5 6 
# but it is the same as our first column here

# %%
# To select frames at regular intervals, we can use the syntax array[start:stop:interval].
print(data[0:10:2,:])
# Out:
# [[ 1.      8.9542  5.8024 11.5478  9.9557]
#  [ 3.      9.0066  6.0637 13.0924 11.3043]
#  [ 5.      9.1294  5.9365 13.5321 10.6279]
#  [ 7.      8.8657  5.9186 12.9312 10.2176]
#  [ 9.      9.4184  6.1993 13.2614 10.366 ]]

# %%
#If you want to go to the end, leave out the end variable, and just use two colons ::.
print(data[0::100,0])
# Out:
# [1.000e+00 1.010e+02 2.010e+02 3.010e+02 4.010e+02 5.010e+02 6.010e+02
#  7.010e+02 8.010e+02 9.010e+02 1.001e+03 1.101e+03 1.201e+03 1.301e+03
#  1.401e+03 1.501e+03 1.601e+03 1.701e+03 1.801e+03 1.901e+03 2.001e+03
#  2.101e+03 2.201e+03 2.301e+03 2.401e+03 2.501e+03 2.601e+03 2.701e+03
#  2.801e+03 2.901e+03 3.001e+03 3.101e+03 3.201e+03 3.301e+03 3.401e+03
#  3.501e+03 3.601e+03 3.701e+03 3.801e+03 3.901e+03 4.001e+03 4.101e+03
#  4.201e+03 4.301e+03 4.401e+03 4.501e+03 4.601e+03 4.701e+03 4.801e+03
#  4.901e+03 5.001e+03 5.101e+03 5.201e+03 5.301e+03 5.401e+03 5.501e+03
#  5.601e+03 5.701e+03 5.801e+03 5.901e+03 6.001e+03 6.101e+03 6.201e+03
#  6.301e+03 6.401e+03 6.501e+03 6.601e+03 6.701e+03 6.801e+03 6.901e+03
#  7.001e+03 7.101e+03 7.201e+03 7.301e+03 7.401e+03 7.501e+03 7.601e+03
#  7.701e+03 7.801e+03 7.901e+03 8.001e+03 8.101e+03 8.201e+03 8.301e+03
#  8.401e+03 8.501e+03 8.601e+03 8.701e+03 8.801e+03 8.901e+03 9.001e+03
# ...

# %%
#Let’s make a plot with every 100 points.
incr_100_x=data[0::100,0]
incr_100_y=data[0::100,1]
plt.figure()
plt.plot(incr_100_x,incr_100_y)

# %% [markdown]
# ## Customizing plot appearance

# %%
plt.figure()
plt.plot(incr_100_x,incr_100_y,'--')

# %%
plt.figure()
plt.plot(incr_100_x,incr_100_y,'o')

# %%
plt.figure()
plt.plot(incr_100_x,incr_100_y,'--o')

# %% [markdown]
# list:
# character	description
# '-'	solid line style
# '--'	dashed line style
# '-.'	dash-dot line style
# ':'	dotted line style
# '.'	point marker
# ','	pixel marker
# 'o'	circle marker
# 'v'	triangle_down marker
# '^'	triangle_up marker
# '<'	triangle_left marker
# '>'	triangle_right marker
# '1'	tri_down marker
# '2'	tri_up marker
# '3'	tri_left marker
# '4'	tri_right marker
# 's'	square marker
# 'p'	pentagon marker
# '*'	star marker
# 'h'	hexagon1 marker
# 'H'	hexagon2 marker
# '+'	plus marker
# 'x'	x marker
# 'D'	diamond marker
# 'd'	thin_diamond marker
# '|'	vline marker
# '_'	hline marker

# %% [markdown]
# colors: ‘b’	blue
# ‘g’	green
# ‘r’	red
# ‘c’	cyan
# ‘m’	magenta
# ‘y’	yellow
# ‘k’	black
# ‘w’	white

# %%
# black dashed line and circular markers.
plt.figure()
plt.plot(incr_100_x,incr_100_y,'k--o')

# %% [markdown]
# ## Multiple Plots with Subplot

# %%
# fig, ax = plt.subplots(nrows, ncolumns)
fig, ax = plt.subplots(len(headers)-1, 1)

# %%
ax.shape
# Out:
# (4,)

# %%
fig2, ax2 = plt.subplots(2,2)
ax2.shape
# Out:
# (2, 2)

# %%
ax[0].plot(data[0::100,0],data[0::100,col])
fig

# %%
ax2[0,0].plot(data[0::100,0],data[0::100,col])
fig2

# %%
fig, ax=plt.subplots(len(headers)-1,1)

for col in range(1, len(headers)):
    ax[col-1].plot(data[0::100,0],data[0::100,col], label=headers[col])
    ax[col-1].set_xlabel('Simulation Frame')
    ax[col-1].set_ylabel('Distance (angstrom)')
    ax[col-1].legend()

# %% [markdown]
# ## Improving the figure

# %%
# figzise for size, sharey=True makes all y axis the same
fig, ax=plt.subplots(len(headers)-1,1, figsize=(10,15), sharey=True)

for col in range(1, len(headers)):
    ax[col-1].plot(data[0::100,0],data[0::100,col], label=headers[col])
    ax[col-1].set_xlabel('Simulation Frame')
    ax[col-1].set_ylabel('Distance (angstrom)')
    ax[col-1].legend()
plt.savefig('all.png',dpi=600)

# %% [markdown]
# ## Writing Functions

# %%
# old code we want to implment a function in
import numpy
import os

file_location = os.path.join('data', 'water.xyz')
xyz_file = numpy.genfromtxt(fname=file_location, skip_header=2, dtype='unicode')
symbols = xyz_file[:, 0]
coordinates = xyz_file[:, 1:]
coordinates = coordinates.astype(float)
num_atoms = len(symbols)
for num1 in range(0, num_atoms):
    for num2 in range(0, num_atoms):
        if num1 < num2:
            x_distance = coordinates[num1, 0] - coordinates[num2, 0]
            y_distance = coordinates[num1, 1] - coordinates[num2, 1]
            z_distance = coordinates[num1, 2] - coordinates[num2, 2]
            bond_length_12 = numpy.sqrt(x_distance ** 2 + y_distance ** 2 + z_distance ** 2)
            if bond_length_12 > 0 and bond_length_12 <= 1.5:
                print(F'{symbols[num1]} to {symbols[num2]} : {bond_length_12:.3f}')
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
def b_dis (atom1_coords,atom2_coords):
    x_distance=atom1_coords[0]-atom2_coords[0]
    y_distance=atom1_coords[1]-atom2_coords[1]
    z_distance=atom1_coords[2]-atom2_coords[2]
    bond_length=np.sqrt(x_distance ** 2 + y_distance ** 2 + z_distance ** 2)
    return bond_length

# %%
#now add this to the code
file_location = os.path.join('data', 'water.xyz')
xyz_file = numpy.genfromtxt(fname=file_location, skip_header=2, dtype='unicode')
symbols = xyz_file[:, 0]
coordinates = xyz_file[:, 1:]
coordinates = coordinates.astype(float)
num_atoms = len(symbols)
for num1 in range(0, num_atoms):
    for num2 in range(0, num_atoms):
        if num1 < num2:
            bond_length=b_dis(coordinates[num1],coordinates[num2])
            if bond_length > 0 and bond_length <= 1.5:
                print(F'{symbols[num1]} to {symbols[num2]} : {bond_length:.3f}')
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
# a function to check if it is a real bond
def bond_check(atom_distance):
    if atom_distance > 0 and atom_distance <= 1.5:
        return True
    else:
        return False
#print(bond_check(1.9))

# %%
# make it takes three arguments (length,min,max)
def bond_check(atom_distance,minn,maxx):
    if atom_distance > minn and atom_distance <= maxx:
        return True
    else:
        return False
#print(bond_check(1,.5,1.5))

# %% [markdown]
# # Function Documentation

# %%
help(bond_check)
#no docs
# Out:
# Help on function bond_check in module __main__:
#
# bond_check(atom_distance, minn, maxx)
#     # make it takes three arguments (length,min,max)

# %%
# can add doc using ''''''
def bond_check(atom_distance,minn,maxx):
    '''
    a function that takes 3 arguments, bond distance, min and max and checks if it works as a bond or nah
    '''
    if atom_distance > minn and atom_distance <= maxx:
        return True
    else:
        return False
help(bond_check)
# Out:
# Help on function bond_check in module __main__:
#
# bond_check(atom_distance, minn, maxx)
#     a function that takes 3 arguments, bond distance, min and max and checks if it works as a bond or nah

# %%
# another ex
def calculate_distance(atom1_coord, atom2_coord):
    """Calculate the distance between two three-dimensional points."""

    x_distance = atom1_coord[0] - atom2_coord[0]
    y_distance = atom1_coord[1] - atom2_coord[1]
    z_distance = atom1_coord[2] - atom2_coord[2]
    bond_length_12 = numpy.sqrt(x_distance**2+y_distance**2+z_distance**2)
    return bond_length_12
help(calculate_distance)
# Out:
# Help on function calculate_distance in module __main__:
#
# calculate_distance(atom1_coord, atom2_coord)
#     Calculate the distance between two three-dimensional points.

# %% [markdown]
# ## Function Default arguments

# %%
# you just set your arugemnt = something and that will make it defualt 
def bond_check(atom_distance,minn=0,maxx=1.5):
    '''
    a function that takes 3 arguments, bond distance, min and max and checks if it works as a bond or nah
    '''
    if atom_distance > minn and atom_distance <= maxx:
        return True
    else:
        return False
print(bond_check(1,minn=.5,maxx=.9))
print(bond_check(1))
print(bond_check(1,.1,3))
# Out:
# False
# True
# True

# %%
#Now that we have our bond_check function, 
#we can use it in our for loop to only print the bond lengths that are really bonds.

num_atoms=len(symbols) #3

for num1 in range(0,num_atoms):
    for num2 in range(0, num_atoms):
        if num1<num2:
            bond_length=b_dis(coordinates[num1],coordinates[num2])
            if bond_check(bond_length) is True: # this is the new line instead of saying the number of bonds
                print(F'{symbols[num1]} to {symbols[num2]} : {bond_length:.3f}')
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
'''
wat_file_path=os.path.join('data','water.xyz')
wat_data=np.genfromtxt(wat_file_path,skip_header=2,dtype='unicode') # error if you don't skip headers
#print(wat_data)
'''
def open_xyz(file):
    #wat_file_path=os.path.join('data','water.xyz')
    xyz_file=np.genfromtxt(fname=file,skip_header=2,dtype='unicode')
    atoms=xyz_file[:,0]
    coords=(xyz_file[:,1:])
    coords=coords.astype(float)
    return atoms, coords
open_xyz('data/water.xyz')
# Out:
# (array(['O', 'H1', 'H2'], dtype='<U9'),
#  array([[ 0.      , -0.007156,  0.965491],
#         [-0.      ,  0.001486, -0.003471],
#         [ 0.      ,  0.931026,  1.207929]]))

# %%
#We’ve now written three functions. Using these functions, our script to print bonded atoms now looks like this:

file_location=os.path.join('data','water.xyz')
atoms, coords=open_xyz(file_location)
num_atoms=len(atoms)

for num1 in range(0,len(atoms)):
    for num2 in range(0,len(atoms)):
        if num1<num2:
            bond_length=b_dis(coords[num1],coords[num2])
            if bond_check(bond_length) is True:
                print(f'{atoms[num1]} to {atoms[num2]} : {bond_length:0.3f} ')
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
def print_bonds(atoms, coords):
    for num1 in range(0,num_atoms):
        for num2 in range(0,num_atoms):
            if num1<num2:
                bond_length=b_dis(coords[num1],coords[num2])
                if bond_check(bond_length) is True:
                    print(f'{atoms[num1]} to {atoms[num2]} : {bond_length:0.3f} ')
print_bonds(atoms,coords)
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %%
#If you were to put all the functions we wrote into a single cell, it looks like this:

import numpy as np
import os 

def calculate_distance(atom1_coord, atom2_coord):
    """Calculate the distance between two three-dimensional points."""

    x_distance = atom1_coord[0] - atom2_coord[0]
    y_distance = atom1_coord[1] - atom2_coord[1]
    z_distance = atom1_coord[2] - atom2_coord[2]
    bond_length = numpy.sqrt(x_distance**2+y_distance**2+z_distance**2)
    return bond_length



def bond_check(atom_distance,minn=0,maxx=1.5):
    '''
    a function that takes 3 arguments, bond distance, min and max and checks if it works as a bond or nah
    '''
    if atom_distance > minn and atom_distance <= maxx:
        return True
    else:
        return False
    


def open_xyz(file):
    '''
    open and xyz file and return a tuple of the atoms and coords
    '''
    xyz_file=np.genfromtxt(fname=file,skip_header=2,dtype='unicode')
    atoms=xyz_file[:,0]
    coords=(xyz_file[:,1:])
    coords=coords.astype(float)
    return atoms, coords


def print_bonds(atoms, coords):
    '''
    read through the coords of an xyz file and print the bond length
    '''
    for num1 in range(0,len(atoms)):
        for num2 in range(0,len(atoms)):
            if num1<num2:
                bond_length=calculate_distance(coords[num1],coords[num2])
                if bond_check(bond_length) is True:
                    print(f'{atoms[num1]} to {atoms[num2]} : {bond_length:0.3f} ')

# %%
#trying out the functions on water and benzyne

wat_file_path=os.path.join('data','water.xyz')
wat_atoms, wat_coords=open_xyz(wat_file_path)

benzene_file_path=os.path.join('data','benzene.xyz')
benzene_atoms, benzene_coords=open_xyz(benzene_file_path)

print('water bond lengths')
print_bonds(wat_atoms,wat_coords)
print('benzene bond lengths')
print_bonds(benzene_atoms,benzene_coords)
# Out:
# water bond lengths
# O to H1 : 0.969
# O to H2 : 0.969
# benzene bond lengths
# C to H : 1.088
# C to C : 1.403
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088

# %%
#using glob to open multiple xyz files
import glob as gb
files_path=os.path.join('data','*.xyz')
file_names=gb.glob(files_path)
#print(file_names)

for file in file_names:
    atoms, coords=open_xyz(file)
    #name=file.split('/')
    #name=file.split('.')
    print(file)
    print_bonds(atoms,coords)
# Out:
# data/benzene.xyz
# C to H : 1.088
# C to C : 1.403
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# data/buckminsterfullerene.xyz
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.395
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.395
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# C to C : 1.395
# C to C : 1.453
# C to C : 1.453
# ...

# %% [markdown]
# # Running code from the Linux Command Line

# %% [markdown]
# ## Creating and running a python input file

# %%
import numpy
import os

def calculate_distance(atom1_coord, atom2_coord):
    x_distance = atom1_coord[0] - atom2_coord[0]
    y_distance = atom1_coord[1] - atom2_coord[1]
    z_distance = atom1_coord[2] - atom2_coord[2]
    bond_length_12 = numpy.sqrt(x_distance**2+y_distance**2+z_distance**2)
    return bond_length_12

def bond_check(atom_distance, minimum_length=0, maximum_length=1.5):
    if atom_distance > minimum_length and atom_distance <= maximum_length:
        return True
    else:
        return False

def open_xyz(filename):
     xyz_file = numpy.genfromtxt(fname=filename, skip_header=2, dtype='unicode')
     symbols = xyz_file[:,0]
     coord = (xyz_file[:,1:])
     coord = coord.astype(float)
     return symbols, coord

file_location = os.path.join('data', 'water.xyz')
symbols, coord = open_xyz(file_location)
num_atoms = len(symbols)
for num1 in range(0,num_atoms):
     for num2 in range(0,num_atoms):
         if num1<num2:
             bond_length_12 = calculate_distance(coord[num1], coord[num2])
             if bond_check(bond_length_12) is True:
                 print(F'{symbols[num1]} to {symbols[num2]} : {bond_length_12:.3f}')
# create this file and run it in terminal, easy peasy
# Out:
# O to H1 : 0.969
# O to H2 : 0.969

# %% [markdown]
# ## Changing your code to accept user inputs

# %% [markdown]
# ### python geom_analysis.py water.xyz
# ### move to the scripts now geom_analysis.py and analyze.py

# %% [markdown]
# # Testing Code with pytest

# %% [markdown]
# ## Writing unit tests

# %% [markdown]
# ## at this point everything is moved to writing scripts on atom or pycharm
